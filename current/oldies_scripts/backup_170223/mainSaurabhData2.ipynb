# %% [markdown]
# ### Dependencies

# %%
import sys, os
from csv import DictWriter

import numpy as np
import pandas as pd
import torch as T
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq
from scipy.signal import detrend

import pynumdiff

from dataclasses import dataclass

import torch_optimizer as optim_all

import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
plt.style.use("seaborn-v0_8-whitegrid")

# %% [markdown]
# ### Physical Model

# %%
def build_true_model(x, t, params):
    """
    A function that gets the displacement, velocity and time as an input, and returns the true vector field output (velocity and acceleration)

    Parameters
    ----------
    x : numpy.ndarray 
        a 2D array containing the displacement in the first column and the velocity in the second one
    t : numpy.ndarray
        an 1D array containing the discrete time values 
    params : parameters dataclass
        the parameters of the run
    Returns
    -------
    numpy.ndarray
        a 2D array with the two vector field values, velocity as first column and acceleration as second, for the given input x and t
    """
    return [x[1], - 2 * params.zeta * params.omega * x[1] - params.omega ** 2 * x[0] - params.friction_force_ratio * np.sign(x[1]) + params.F0 * np.cos(params.forcing_freq * t)]

# %%
def generate_data(params):
    """
    A function that solves the system's equation and generates the ground truth data based on the defined run parameters

    Parameters
    ----------
    params : parameters dataclass
        the parameters of the run
    Returns
    -------
    numpy.ndarray
        an 1D array with the discrete time instances
    numpy.ndarray
        a 2D array with the ground truth data, displacements as first column and velocities as second
    """
    #Generate (noisy) measurements - Training Data
    ts = np.arange(0, params.timefinal, params.timestep)

    # Make sure that in case of a free vibration analysis, friction and forcing terms are dropped
    if params.analysis_type == "free":
        params.friction_force_ratio = 0
        params.F0 = 0

    # Solve the equation
    sol = solve_ivp(
        lambda t, x: build_true_model(x, t, params), 
        t_span=[ts[0], ts[-1]], y0=params.x0, t_eval=ts
        )

    return ts, np.transpose(sol.y)

# %% [markdown]
# ### Get measurments from csv file

# %%
def get_measurments(csv_path, rows_skip=4, detrend_flag=True, delta_T=30):
    """
    A function that reads the csv file containing the experimental data and returns the absolute and relative displacements 

    Parameters
    ----------
    csv_path : str 
        the path of the csv file
    rows_skip : int
        the number of rows in the csv that does not contain any data (header)
    detrend_flag : bool
        a flag that if set to True (default value) the data will be editted to remove a rigid body contribution
    delta_T : int
        a time increment in case the timestamp does not start from zero
    Returns
    -------
    numpy.ndarray
        an 1D array containing the timestamps
    numpy.ndarray
        an 1D array containing the absolute displacements
    numpy.ndarray
        an 1D array containing the relative displacements
    """
    data = pd.read_csv(csv_path, skiprows=rows_skip)
    
    if delta_T:
        data.iloc[:, 0] -= 30
    
    times = data.iloc[:, 0].to_numpy()
    abs_displ = data.iloc[:, 1].to_numpy()
    rel_displ = data.iloc[:, 2].to_numpy()
    
    if detrend_flag:
        abs_displ = detrend(abs_displ, type='constant')
        rel_displ = detrend(rel_displ, type='constant')
    
    # Transform the units from millimeters to meters
    rel_displ /= 1000
    abs_displ /= 1000

    return times, abs_displ, rel_displ

# %%
def read_saurabh_data(filepath, row_skip=1, detrend_flag=True):
    data = pd.read_csv(filepath, skiprows=row_skip)

    displsMilimeters = data.iloc[:, 2].to_numpy()
    excitationMilimeters = data.iloc[:, 1].to_numpy()
    displs = displsMilimeters * 0.001
    excite = excitationMilimeters * 0.001
    startExcitation = np.nonzero(np.abs(displs - displs[0]) >= 1e-6)[0][0]
    displs = displs[startExcitation:]
    excite = excite[startExcitation:]

    displs = detrend(displs, type='constant')
    excite = detrend(excite, type='constant')

    return displs, excite

# %% [markdown]
# ### Get the excitation frequency content (through the Forward Fourier Transform)

# %%
def get_frequency_content(displs, no_sample_points, sample_spacing):
    """
    A function that applies the Forward Fourier Transform to decompose the signal into its frequency content 

    Parameters
    ----------
    displs : numpy.ndarray 
        an 1D array containing the displacements (response quantity)
    no_sample_points : int
        the number of sample points that will be used
    sample_spacing : float
        the size of the sampling intervals
    Returns
    -------
    numpy.ndarray
        the involved frequencies
    numpy.ndarray
        the spectral density of each of the frequencies
    """
    yf = fft(displs)
    freqs = fftfreq(no_sample_points, sample_spacing)[: no_sample_points // 2]
    spectral_density = 2.0 / no_sample_points * np.abs(yf[0 : no_sample_points // 2])

    return freqs, spectral_density

# %% [markdown]
# ### Coefficients dictionary

# %%
class CoeffsDictionary(T.nn.Module):
    """
    A class for initializing, storing, and updating the ksi coefficients
    These coefficients are the linear weights of a neural network
    The class inherits from the torch.nn.Module
    """
    def __init__(self, n_combinations):

        super(CoeffsDictionary, self).__init__()
        self.linear = T.nn.Linear(n_combinations, 1, bias=False)
        # Setting the weights to zeros
        self.linear.weight = T.nn.Parameter(0 * self.linear.weight.clone().detach())
    
    def forward(self, x):
        
        return self.linear(x)

# %% [markdown]
# ### Features function

# %%
def apply_features(x, t, params, torch_flag=True):
    """
    Applies the feature candidates to the given data

    Parameters
    ----------
    x : numpy.ndarray or torch.Tensor
        a 2D array/tensor containing the displacement in the first column and the velocity in the second one
    t : numpy.ndarray or torch.Tensor
        an 1D array/tensor containing the discrete time values 
    params : parameters dataclass
        the parameters of the run
    torch_flag : bool
        if True, the type of x, t and return object is torch.Tensor, otherwise numpy.ndarray
    Returns
    -------
    numpy.ndarray or torch.Tensor
        a 2D array/tensor with the two vector field values, velocity as first column and acceleration as second, 
        applying the assumed features on the given input x and t
    
    """
    if torch_flag:
        return T.column_stack(
            (
                *[T.cos(ph * t) for ph in params.cos_phases], # cosine features
                *[T.sin(ph * t) for ph in params.sin_phases], # sine features
                *[T.sign(x[:, 0]),] * params.x_sgn_flag, # x signum feature
                *[T.sign(x[:, 1]),] * params.y_sgn_flag, # y signum feature
                *[T.ones(size=(x.shape[0],))] * (params.poly_order >= 0), 
                *[x[:, 0], x[:, 1]] * (params.poly_order >= 1),
                *[x[:, 0] ** 2, x[:, 0] * x[:, 1], x[:, 1] ** 2] * (params.poly_order >= 2),
                *[x[:, 0] ** 3, x[:, 0] ** 2 * x[:, 1], x[:, 0] * x[:, 1] ** 2, x[:, 1] ** 3,] * (params.poly_order >= 3),
                *[x[:, 0] ** 4, x[:, 0] ** 3 * x[:, 1], x[:, 0] ** 2 * x[:, 1] ** 2, x[:, 0] * x[:, 1] ** 3, x[:, 1] ** 4] * (params.poly_order >= 4), # polynomial features
            )
        )
    else:
        return np.column_stack(
        (
            *[np.cos(ph * t) for ph in params.cos_phases], # cosine features                
            *[np.sin(ph * t) for ph in params.sin_phases], # sine features                
            *[np.sign(x[:, 0]),] * params.x_sgn_flag, # x signum feature 
            *[np.sign(x[:, 1]),] * params.y_sgn_flag, # y signum feature
            *[np.ones(shape=(x.shape[0],))] * (params.poly_order >= 0), 
            *[x[:, 0], x[:, 1]] * (params.poly_order >= 1),
            *[x[:, 0] ** 2, x[:, 0] * x[:, 1], x[:, 1] ** 2] * (params.poly_order >= 2),
            *[x[:, 0] ** 3, x[:, 0] ** 2 * x[:, 1], x[:, 0] * x[:, 1] ** 2, x[:, 1] ** 3,] * (params.poly_order >= 3),
            *[x[:, 0] ** 4, x[:, 0] ** 3 * x[:, 1], x[:, 0] ** 2 * x[:, 1] ** 2, x[:, 0] * x[:, 1] ** 3, x[:, 1] ** 4] * (params.poly_order >= 4), # polynomial features
        )
    )

# %% [markdown]
# #### Store the selected features as strings in a list

# %%
def get_feature_names(params):
    """"
    A function that stores the assumed features as strings

    Parameters
    ----------
    params : parameters dataclass
        the parameters of the run

    Returns
    -------
    list
        the list containing the assumed features as strings
    """
    return [*[f"cos({ph:.1f} t)" for ph in params.cos_phases], 
            *[f"sin({ph:.1f} t)" for ph in params.sin_phases], 
            *["sgn(x)",] * params.x_sgn_flag,
            *["sgn(y)",] * params.y_sgn_flag,
            *["1",] * (params.poly_order >= 0),
            *["x", "y"] * (params.poly_order >= 1),
            *["x^2", "xy", "y^2"] * (params.poly_order >= 2),
            *["x^3", "x^2y", "xy^2", "y^3"] * (params.poly_order >= 3),
            *["x^4", "x^3y", "x^2y^2", "xy^3", "y^4"] * (params.poly_order >= 4),]

# %% [markdown]
# #### Print the learnt equation

# %%
def print_learnt_equation(learnt_coeffs, params):
    """"
    A function that combines the learnt coefficients and the assumed features 
    to form the governing equation

    Parameters
    ----------
    learnt_coeffs : numpy.ndarray
        an array containing the learnt coefficients
    params : parameters dataclass
        the parameters of the run

    Returns
    -------
    str
        the governing equation
    """
    feature_names = get_feature_names(params)
    
    string_list = [f'{"+" if coeff > 0  else ""}{coeff:.3f} {feat}' for coeff, feat in zip(np.squeeze(learnt_coeffs, axis=1), feature_names) if np.abs(coeff) > 1e-5]

    equation = " ".join(string_list)

    if equation[0] == "+":
        equation = equation[1:]
    
    return equation

# %% [markdown]
# ### 4th order Runge-Kutta constraint function

# %%
# def apply_rk4_SparseId(x, coeffs, times, timesteps, params):
#     """
#     A function that applies the fourth order Runge-Kutta scheme to the given data in order to derive the ones in the following timestep
#     During this process the approximate derivatives are used
   
#     Parameters
#     ----------
#     x : torch.Tensor
#         a 2D tensor containing the displacement in the first column and the velocity in the second one
#     coeffs : CoeffsDictionary object
#         the neural network with the sought coefficients as its weights
#     times : torch.Tensor
#         an 1D tensor containing the discrete time values
#     timesteps : torch.Tensor
#         an 1D tensor containing the discrete time intervals
#     params : parameters dataclass
#         the parameters of the run

#     Returns
#     -------
#     torch.Tensor
#         Predictions of both displacement and velocity for the next timesteps
    
#     """
#     d1 = apply_features(x, times, params)
#     k1 = T.column_stack((x[:, 1].unsqueeze(1), (- 0.658 * x[:, 1] - 386.766 * x[:, 0]).unsqueeze(1) + 0.0018434984 * np.cos(0.995 * 12.5814253 * times + 1.1624975) - 0.995 * 12.5814253 * 0.0018434984 * np.cos(0.995 * 12.5814253 * times + 1.1624975) + coeffs(d1)))

   
#     xtemp = x + 0.5 * timesteps * k1
#     d2 = apply_features(xtemp, times + 0.5 * timesteps, params)
#     k2 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.658 * xtemp[:, 1] - 386.766 * xtemp[:, 0]).unsqueeze(1) + 0.0018434984 * np.cos(0.995 * 12.5814253 * (times + 0.5 * timesteps) + 1.1624975) - 0.995 * 12.5814253 * 0.0018434984 * np.cos(0.995 * 12.5814253 * (times + 0.5 * timesteps) + 1.1624975) + coeffs(d2)))


#     xtemp = x + 0.5 * timesteps * k2
#     d3 = apply_features(xtemp, times + 0.5 * timesteps, params)    
#     k3 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.658 * xtemp[:, 1] - 386.766 * xtemp[:, 0]).unsqueeze(1) + 0.0018434984 * np.cos(0.995 * 12.5814253 * (times + 0.5 * timesteps) + 1.1624975) - 0.995 * 12.5814253 * 0.0018434984 * np.cos(0.995 * 12.5814253 * (times + 0.5 * timesteps) + 1.1624975) + coeffs(d3)))


#     xtemp = x + timesteps * k3
#     d4 = apply_features(xtemp, times + timesteps, params)
#     k4 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.658 * xtemp[:, 1] - 386.766 * xtemp[:, 0]).unsqueeze(1) + 0.0018434984 * np.cos(0.995 * 12.5814253 * (times + timesteps) + 1.1624975) - 0.995 * 12.5814253 * 0.0018434984 * np.cos(0.995 * 12.5814253 * (times + timesteps) + 1.1624975) + coeffs(d4)))


#     return x + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timesteps

# %%
def apply_rk4_SparseId(x, u_1, u_m, u_2, coeffs, times, timesteps, params):
    """
    A function that applies the fourth order Runge-Kutta scheme to the given data in order to derive the ones in the following timestep
    During this process the approximate derivatives are used
   
    Parameters
    ----------
    x : torch.Tensor
        a 2D tensor containing the displacement in the first column and the velocity in the second one
    coeffs : CoeffsDictionary object
        the neural network with the sought coefficients as its weights
    times : torch.Tensor
        an 1D tensor containing the discrete time values
    timesteps : torch.Tensor
        an 1D tensor containing the discrete time intervals
    params : parameters dataclass
        the parameters of the run

    Returns
    -------
    torch.Tensor
        Predictions of both displacement and velocity for the next timesteps
    
    """
    d1 = apply_features(x, times, params)
    k1 = T.column_stack((x[:, 1].unsqueeze(1), (- 0.658 * x[:, 1] - 386.766 * x[:, 0] + 0.658 * u_1[:, 1] + 386.766 * u_1[:, 0]).unsqueeze(1) + coeffs(d1)))

   
    xtemp = x + 0.5 * timesteps * k1
    d2 = apply_features(xtemp, times + 0.5 * timesteps, params)
    k2 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.658 * xtemp[:, 1] - 386.766 * xtemp[:, 0] + 0.658 * u_m[:, 1] + 386.766 * u_m[:, 0]).unsqueeze(1) + coeffs(d2)))


    xtemp = x + 0.5 * timesteps * k2
    d3 = apply_features(xtemp, times + 0.5 * timesteps, params)    
    k3 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.658 * xtemp[:, 1] - 386.766 * xtemp[:, 0] + 0.658 * u_m[:, 1] + 386.766 * u_m[:, 0]).unsqueeze(1) + coeffs(d3)))


    xtemp = x + timesteps * k3
    d4 = apply_features(xtemp, times + timesteps, params)
    k4 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.658 * xtemp[:, 1] - 386.766 * xtemp[:, 0] + 0.658 * u_2[:, 1] + 386.766 * u_2[:, 0]).unsqueeze(1) + coeffs(d4)))


    return x + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timesteps

# %%
# def apply_rk4_SparseId(x, u, umid, coeffs, times, timesteps, params):
#     """
#     A function that applies the fourth order Runge-Kutta scheme to the given data in order to derive the ones in the following timestep
#     During this process the approximate derivatives are used
   
#     Parameters
#     ----------
#     x : torch.Tensor
#         a 2D tensor containing the displacement in the first column and the velocity in the second one
#     coeffs : CoeffsDictionary object
#         the neural network with the sought coefficients as its weights
#     times : torch.Tensor
#         an 1D tensor containing the discrete time values
#     timesteps : torch.Tensor
#         an 1D tensor containing the discrete time intervals
#     params : parameters dataclass
#         the parameters of the run

#     Returns
#     -------
#     torch.Tensor
#         Predictions of both displacement and velocity for the next timesteps
    
#     """
#     d1 = apply_features(x, times, params)
#     k1 = T.column_stack((x[:, 1].unsqueeze(1), (- 0.0658 * (150 / 98) * x[:, 1] - 358.706 * (150 / 98) * x[:, 0] + 0.0658 * u[:-1, 1] + 358.706 * u[:-1, 0]).unsqueeze(1) + coeffs(d1)))

   
#     xtemp = x + 0.5 * timesteps * k1
#     d2 = apply_features(xtemp, times + 0.5 * timesteps, params)
#     k2 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.0658 * (150 / 98) * xtemp[:, 1] - 358.706 * (150 / 98) * xtemp[:, 0] + 0.0658 * umid[:, 1] + 358.706 * umid[:, 0]).unsqueeze(1) + coeffs(d2)))


#     xtemp = x + 0.5 * timesteps * k2
#     d3 = apply_features(xtemp, times + 0.5 * timesteps, params)    
#     k3 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.0658 * (150 / 98) * xtemp[:, 1] - 358.706 * (150 / 98) * xtemp[:, 0] + 0.0658 * umid[:, 1] + 358.706 * umid[:, 0]).unsqueeze(1) + coeffs(d3)))


#     xtemp = x + timesteps * k3
#     d4 = apply_features(xtemp, times + timesteps, params)
#     k4 = T.column_stack((xtemp[:, 1].unsqueeze(1), (- 0.0658 * (150 / 98) * xtemp[:, 1] - 358.706 * (150 / 98) * xtemp[:, 0] + 0.0658 * u[1:, 1] + 358.706 * u[1:, 0]).unsqueeze(1) + coeffs(d4)))


#     return x + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timesteps

# %% [markdown]
# ### Torch standard scaler

# %%
def scale_torch(unscaled_tensor, params):
    """
    A function that applies a standard scaling to a torch tensor

    Parameters
    ----------
    unscaled_tensor ; torch.tensor
        a 2D tensor we wish to scale
    params : parameters dataclass
        the parameters of the run

    Returns
    -------
    torch.tensor
        the scaled tensor
    """
    return (unscaled_tensor - params.mus) / params.stds

# %% [markdown]
# ### Learning function

# %%
def learn_sparse_model(coeffs, train_set, excitation_set, times, params, lr_reduction=10):
    """"
    A function that calculates which ksi coefficients lead to optimal prediction
    The updating of the coefficients is performed in a deep learning fashion

    Parameters
    ----------
    coeffs : CoeffsDictionary object
        the neural network with the sought coefficients as its weights
    train_set : torch.Tensor
        a 2D tensor containing the displacement in the first column and the velocity in the second one
    times : torch.Tensor
        an 1D tensor containing the discrete time values
    params : parameters dataclass
        the parameters of the run
    lr_reduction : int
        the value that the learning rate is divided by in each training batch

    Returns
    -------
    coeffs : CoeffsDictionary object
        the neural network with the updated/learnt coefficients as its weights
    loss_track : numpy.ndarray
        a 2D array containing the loss for each training batch (row), for each epoch (column)
    """
    # Define optimizer
    opt_func = optim_all.RAdam(
        coeffs.parameters(), lr=params.lr, weight_decay=params.weightdecay
    )
    # Define loss function
    criteria = T.nn.MSELoss()
    # pre-allocate memory for loss_fuction
    loss_track = np.zeros((params.num_iter, params.num_epochs))

    # Training 
    for p in range(params.num_iter):
        for g in range(params.num_epochs):
            coeffs.train()

            opt_func.zero_grad()

            loss_new = T.autograd.Variable(T.tensor([0.0], requires_grad=True))
            weights = 2 ** (-0.5 * T.linspace(0, 0, 1))

            timesteps_i = T.tensor(np.diff(times, axis=0)).float()
            u_middle = 0.5 * (excitation_set[:-1] + excitation_set[1:])

            # One forward step predictions
            y_pred = apply_rk4_SparseId(train_set[:-1], excitation_set[:-1], u_middle, excitation_set[1:], coeffs, times[:-1], timesteps=timesteps_i, params=params)

            # One backward step predictions
            y_pred_back = apply_rk4_SparseId(train_set[1:], excitation_set[1:], u_middle, excitation_set[:-1], coeffs, times[1:] , timesteps=-timesteps_i, params=params)
           
            if params.scaling:
                y_pred_scaled = scale_torch(y_pred, params)
                y_pred_back_scaled = scale_torch(y_pred_back, params)
                train_set_scaled = scale_torch(train_set, params)
                
                loss_new += criteria(y_pred_scaled, train_set_scaled[1:]) + weights[0] * criteria(
                    y_pred_back_scaled, train_set_scaled[:-1])
                
            else:
                loss_new += criteria(y_pred, train_set[1:]) + weights[0] * criteria(
                    y_pred_back, train_set[:-1]
                )

            loss_track[p, g] += loss_new.item()
            loss_new.backward()
            opt_func.step()

            sys.stdout.write("\r [Iter %d/%d] [Epoch %d/%d] [Training loss: %.2e] [Learning rate: %.2e]" % (p + 1, params.num_iter, g + 1, params.num_epochs, loss_track[p, g], opt_func.param_groups[0]["lr"],))

        # Removing the coefficients smaller than tol and set gradients w.r.t. them to zero
        # so that they will not be updated in the iterations
        Ws = coeffs.linear.weight.detach().clone()
        Mask_Ws = (Ws.abs() > params.tol_coeffs).type(T.float)
        coeffs.linear.weight = T.nn.Parameter(Ws * Mask_Ws)

        coeffs.linear.weight.register_hook(lambda grad: grad.mul_(Mask_Ws))
        new_lr = opt_func.param_groups[0]["lr"] / lr_reduction
        opt_func = optim_all.RAdam(coeffs.parameters(), lr=new_lr, weight_decay=params.weightdecay)

    return coeffs, loss_track

# %%
def setup_directories(child_dir):
    """"
    A function that checks if the directory, where the run's data will be saved, exists. 
    In case it does, stored date will be overwritten, otherwise, this new directory will be created

    Parameters
    ----------
    child_dir : str
        the path of the directory to be created
    """
    if os.path.isdir(child_dir):
        print("""
        ------------------------------------------------------------------------------
        WARNING, the directory already exists, you are about to overwrite some data!!!
        ------------------------------------------------------------------------------
        """, sep=os.linesep)
    else:
        os.makedirs(child_dir)

# %%
def store_results(params, loss, coeffs, parent_dir, child_dir):
    """"
    A function that appends the hyperparameters and the derived solution to the .csv with all the stored results.
    It also saves the losses and the derived ksi coefficients

    Parameters
    ----------
    params : parameters dataclass
        the parameters of the run
    loss : numpy.ndarray
        the losses stored during every epoch of every training batch
    coeffs : numpy.ndarray
        the ksi coefficients derived after applying RK4SINDy
    parent_dir : str
        the path of the directory that contains info for all runs
    child_dir : str
        the path of the directory that will contain the results of the current run
    """  
    param_dict = params.__dict__
    csv_file = 'hyperparameters.csv'

    with open(os.path.join(parent_dir, csv_file), "a", newline='') as file_object:
        dict_writer_object = DictWriter(file_object, fieldnames=list(param_dict.keys()))

        if params.id == "1":
            dict_writer_object.writeheader()
        
        dict_writer_object.writerow(param_dict)

    np.save(os.path.join(child_dir, "losses.npy"), loss)
    np.save(os.path.join(child_dir, "coeffs.npy"), coeffs)

# %%
def plot_results(times, exact_sol, measurements, learnt_sol, child_dir, type_flag='d', save_flag=True, figsize=(16, 8)):
    """"
    A function that plots and saves the comparison between the learnt solution, the exact solution and the used measurements

    Parameters
    ----------
    times : numpy.ndarray
        an 1D matrix containing the discrete time values
    exact_sol : numpy.ndarray
        a 2D array containing displacement and velocity values for each time step according to the exact equation 
    measurements : numpy.ndarray
        a 2D array containing noisy displacement and velocity measurement for each time step 
    learnt_sol : str
        a 2D array containing displacement and velocity values for each time step according to the learnt equation 
    child_dir : str
        the path of the directory that will contain the results of the current run
    type_flag : bool
        if set to 'd', the displacement plot will be generated/saved, if set to 'v', the velocity one
    """ 
    plt.figure(figsize=figsize)

    plt.plot(times[::20], measurements[::20], "ro", markersize=5, label="Measurements")
    plt.plot(times, learnt_sol, "k--", linewidth=2, label="RK4-SINDy")
    plt.plot(times, exact_sol, alpha=0.3, linewidth=4, label="Ground truth")

    plt.legend(fontsize=22)#, bbox_to_anchor=(1., 0.6))#, loc='upper right')
    
    plt.xlabel(r"$t \, \, \mathrm{[s]}$", fontsize=24)
    if type_flag == 'd':
        plt.ylabel(r"$x(t) \, \, \mathrm{[m]}$", fontsize=24)
    elif type_flag == 'v':
        plt.ylabel(r"$\dot{x}(t) \, \, \mathrm{[m/s]}$", fontsize=24)
    else:
        print("A wrong type_flag was given\nIt should be either 'd' for displacements, or 'v' for velocities")
        
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    if save_flag:
        plt.savefig(os.path.join(child_dir, f"{type_flag}.png"), bbox_inches='tight')

    plt.show()

# %%
def plot_error(times, exact_sol, learnt_sol, nrmse, child_dir, type_flag='d', save_flag=True, figsize=(16,12)):
    """"
    A function that plots and saves the squared error between the learnt solution and the exact one

    Parameters
    ----------
    times : numpy.ndarray
        an 1D matrix containing the discrete time values
    exact_sol : numpy.ndarray
        a 2D array containing displacement and velocity values for each time step according to the exact equation 
    learnt_sol : str
        a 2D array containing displacement and velocity values for each time step according to the learnt equation 
    rmse : numpy.ndarray
        a 2D array containing the root mean squared error between the exact solution and the learnt one, for both displacements and velocities
    child_dir : str
        the path of the directory that will contain the results of the current run
    type_flag : bool
        if set to 'd', the displacement plot will be generated/saved, if set to 'v', the velocity one
    """ 
    if type_flag == 'd':
        ind = 0
    elif type_flag == 'v':
        ind = 1
    else:
        print("A wrong type_flag was given\nIt should be either 'd' for displacements, or 'v' for velocities")
    
    squaredError = np.abs(exact_sol - learnt_sol)

    _, ax = plt.subplots(figsize=figsize)

    ax.plot(times, squaredError[:, ind], label="Squared Error")

    textstr = f"NRMSE : {nrmse[ind]:.4f}"

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

    # place a text box in upper left in axes coords
    ax.text(0.75, 0.95, textstr, transform=ax.transAxes, fontsize=24,
            verticalalignment='top', bbox=props)

    ax.set_xlabel(r"$t \, \, \mathrm{[s]}$", fontsize=24)
    if ind == 0:
        ax.set_ylabel(r"$\mid x_{\mathrm{true}} - x_{\mathrm{learned}} \mid \, \, \mathrm{[m]}$", fontsize=24)
    elif ind == 1:
        ax.set_ylabel(r"$\mid \dot{x}_{\mathrm{true}} - \dot{x}_{\mathrm{learned}}\mid \, \, \mathrm{[m/s]}$", fontsize=24)

    ax.tick_params(axis='both', which='major', labelsize=20)

    if save_flag:
        plt.savefig(os.path.join(child_dir, "err.png"), bbox_inches='tight')

    plt.show()

# %% [markdown]
# #### Random seed

# %%
randSeed = 42

T.manual_seed(randSeed)
np.random.seed(seed=randSeed)

# %% [markdown]
# ### Parameters dataclass

# %%
@dataclass
class parameters:
    # Learning hyperparameters
    num_epochs = 2000 # 5000
    num_iter = 3 # 2
    lr = 1. # 1.
    weightdecay = 0.0
    tol_coeffs: float = 5e-2
    scaling: bool = True

    timestep: float = 5e-4 # 5e-4
    
    # analysis specifications
    id: str = "100"
    data_source: int = 1 # 0: artificially generated, 1: experimental setup
    analysis_index = 1 # 0: "free", 1: "forced with known terms", 2: "forced global response"
    save_analysis = True 
    

    # Assumed features
    poly_order: int = 1
    cos_phases: np.ndarray = np.arange(0.6, 1.81, 0.2)
    sin_phases: np.ndarray = ()
    x_sgn_flag: bool = True
    y_sgn_flag: bool = True
    
Params = parameters()

analysis_types = ("free", "forced with known terms", "forced global response")
Params.analysis_type = analysis_types[Params.analysis_index]

num_real = 1

# %%
if Params.data_source == 0:
    Params.timefinal = 50

    Params.omega: float =  1.0
    Params.zeta: float = 0.05
    Params.forcing_freq: float = 1.2 # 0.3 or 1.2
    Params.F0: float = 1.0
    Params.friction_force_ratio: float = 0.5
    Params.x0: tuple = (0.1, 0.1)

    Params.true_omega = 1.0
    Params.true_zeta = 0.05

    Params.noisy_measure_flag: bool = False
    Params.noise_level: float = 1e-1
    Params.noisy_input_flag: bool = False
    Params.omega_noise: float = 5e-2
    Params.zeta_noise: float = 2e-1

    ts, x_denoised = generate_data(Params)

    #Generate noisy measurements
    if Params.noisy_measure_flag:
        x = np.random.normal(loc=x_denoised, scale=Params.noise_level * np.abs(x_denoised), size=x_denoised.shape)
    else:
        x = x_denoised
    
    # Contaminate omega and zeta with noise
    if Params.noisy_input_flag:
        Params.omega = np.clip(np.random.normal(loc=Params.true_omega, scale=Params.omega_noise * Params.true_omega), a_max=None, a_min=0.1)
        Params.zeta = np.clip(np.random.normal(loc=Params.true_zeta, scale=Params.zeta_noise * Params.true_zeta), a_max=0.99, a_min=0.01)
    else:
        Params.omega = Params.true_omega
        Params.zeta = Params.true_zeta

elif Params.data_source == 1:
    
    # Params.reduce_stop = 20000
    # Params.reduce_step = 4

    # slice_index = -1

    # measurements_path = "\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\measurements\\s_s_300g_130_2kHz.csv"
    measurements_path = "\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\measurements\\Saurabh\\60.52.csv"
    # measurements_path = "\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\measurements\\Saurabh\\70.83.csv"
    # measurements_path = "\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\measurements\\Saurabh\\82.26.csv"
    # measurements_path = "\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\measurements\\Saurabh\\110.csv"
    # measurements_path = "\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\measurements\\Saurabh\\120.csv"

    displs, displsExc = read_saurabh_data(measurements_path, row_skip=0)
    # _, vels = pynumdiff.smooth_finite_difference.gaussiandiff(displs, Params.timestep, [100], options={'iterate': False})
    # _, velsExc = pynumdiff.smooth_finite_difference.gaussiandiff(displsExc, Params.timestep, [100], options={'iterate': False})
    _, vels = pynumdiff.linear_model.spectraldiff(displs, Params.timestep, [0.002])
    _, velsExc = pynumdiff.linear_model.spectraldiff(displsExc, Params.timestep, [0.002])
    vels2 = np.gradient(displs, Params.timestep)
    vels3 = np.gradient(displsExc, Params.timestep)

    # freqs, freq_dens = get_frequency_content(displs, displs.shape[0], Params.timestep)
    freqs, freq_dens = get_frequency_content(displsExc, displsExc.shape[0], Params.timestep)

    forcing_freq = freqs[freq_dens.argmax()] * 2 * np.pi
    print(f"The forcing frequency is: {forcing_freq:.2f} rad/s")

    Params.cos_phases = np.arange(0.8 * forcing_freq, 1.21 * forcing_freq, 0.1 * forcing_freq)
    # Params.sin_phases = np.arange(0.8 * forcing_freq, 1.21 * forcing_freq, 0.1 * forcing_freq)
    # Params.cos_phases = np.arange(forcing_freq, 1.1 * forcing_freq, forcing_freq)
    # Params.sin_phases = np.arange(forcing_freq, 1.1 * forcing_freq, forcing_freq)
    # Params.cos_phases = ()
    Params.sin_phases = ()
    
    # displs = displs[:slice_index]
    # vels = vels[:slice_index]

    ts = np.arange(0, displs.size*Params.timestep, Params.timestep)

    # _, rel_vels = pynumdiff.smooth_finite_difference.gaussiandiff(rel_x, Params.timestep, [50], options={'iterate': False})
    # _, rel_vels = pynumdiff.linear_model.spectraldiff(rel_x, Params.timestep, [0.01])
    # _, abs_vels = pynumdiff.linear_model.spectraldiff(abs_x, Params.timestep, [0.05])
    # abs_vels = np.gradient(abs_x, Params.timestep)

    # x = np.vstack((displs, vels, displsExc, velsExc)).T
    x = np.vstack((displs, vels)).T
    u = np.vstack((displsExc, velsExc)).T
    Params.x0 = x[0]
    
    # Params.cos_phases = np.arange(forcing_freq, 1.21 * forcing_freq, forcing_freq)
    # Params.sin_phases = np.arange(forcing_freq, 1.21 * forcing_freq, forcing_freq)
    # print(Params.cos_phases)
# Out:
# The forcing frequency is: 12.58 rad/s

# %% [markdown]
# Mass, $m = 3.0799$ kg <br>
# Stiffness, $k = 1190$ N/m <br>
# Natural frequency, $\omega _n = 19.656$ rad/s<br>
# Viscous damping coefficient, $c = 0.264$ Ns/m<br>
# Friction coefficient, $\mu = 0.274$<br>
# Normal force, $N=M\,g=1.472$ N

# %%
Params.reduce_start = 0
Params.reduce_stop = 8000
Params.reduce_step = 20
ts, x, u = ts[Params.reduce_start:Params.reduce_stop:Params.reduce_step], x[Params.reduce_start:Params.reduce_stop:Params.reduce_step], u[Params.reduce_start:Params.reduce_stop:Params.reduce_step]
ts -= ts[0]
Params.x0 = x[0]

# %%
_, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(20,16))
# _, (ax1, ax2) = plt.subplots(nrows=2, figsize=(20,8))
ax1.plot(ts, x[:, 0])
ax2.plot(ts, x[:, 1])
ax3.plot(ts, u[:, 0])
ax3.plot(ts, u[:, 0])
phi = np.arccos(u[0][0] / u[:, 0].max())
ax3.plot(ts, u[:, 0].max() * np.cos(0.995 * forcing_freq * ts + phi))
ax4.plot(ts, u[:, 1])
ax2.plot(ts, vels2[Params.reduce_start:Params.reduce_stop:Params.reduce_step], alpha=0.3)
ax4.plot(ts, vels3[Params.reduce_start:Params.reduce_stop:Params.reduce_step], alpha=0.3)
plt.xlabel(r"$t$ [s]", fontsize=24)
ax1.set_ylabel(r"$x(t)$ [m]", fontsize=24)
ax2.set_ylabel(r"$\dot{x}(t)$ [m/s]", fontsize=24)
ax1.set_xlim((-0.1, 1.01 * ts[-1]))
ax2.set_xlim((-0.1, 1.01 * ts[-1]))
ax3.set_xlim((-0.1, 1.01 * ts[-1]))
ax4.set_xlim((-0.1, 1.01 * ts[-1]))
plt.show()

# %%
def learned_model(xx, uu, tt, ksis):
    # return np.array([xx[1], - 358.706 * xx[0]
    #                         - 0.0658 * xx[1]
    #                         + 358.706 * uu[0]
    #                         + 0.0658 * uu[1]
    return np.array([xx[1], - 386.766 * xx[0]
                            - 0.658 * xx[1]
                            + 386.766 * uu[0]
                            + 0.658 * uu[1]
                            - 0.131 * np.sign(xx[1])], dtype=object)
                            # + (apply_features( 
                            #             np.expand_dims(xx, axis=0), 
                            #             tt, 
                            #             params=Params,
                            #             torch_flag=False
                            #         ) @ ksis).item()], dtype=object)

# %%
# def rk4th_onestep(model, x_, t_, ksis, timestep=1e-2):
#     k1 = model(x_, t_, ksis)
#     k2 = model(x_ + 0.5 * timestep * k1, t_ + 0.5 * timestep, ksis)
#     k3 = model(x_ + 0.5 * timestep * k2, t_ + 0.5 * timestep, ksis)
#     k4 = model(x_ + 1.0 * timestep * k3, t_ + 1.0 * timestep, ksis)
#     return x_ + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timestep

# %%
def rk4th_onestep(model, x_, u_, u_mid, u_n, t_, ksis, timestep=1e-2):
    k1 = model(x_, u_, t_, ksis)
    k2 = model(x_ + 0.5 * timestep * k1, u_mid, t_ + 0.5 * timestep, ksis)
    k3 = model(x_ + 0.5 * timestep * k2, u_mid, t_ + 0.5 * timestep, ksis)
    k4 = model(x_ + 1.0 * timestep * k3, u_n, t_ + 1.0 * timestep, ksis)
    return x_ + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timestep

# %% [markdown]
# ### Learn sparse solution

# %%
for _ in range(num_real):
    # increment the id of the run
    Params.id = str(int(Params.id) + 1)
        
    if Params.scaling:
        Params.mus = T.tensor(np.mean(x, axis=0)).float().unsqueeze(0)
        Params.stds = T.tensor(np.std(x, axis=0)).float().unsqueeze(0)

    # Learn the coefficients
    train_dset = T.tensor(x).float()
    excitation_dset = T.tensor(u).float()
    times = T.tensor(ts).unsqueeze(1).float()

    no_of_terms = apply_features(train_dset[:2], times[:2], params=Params).shape[1]

    coeffs = CoeffsDictionary(no_of_terms)

    # Learning Coefficients
    coeffs, loss_track = learn_sparse_model(coeffs, train_dset, excitation_dset, times, Params, lr_reduction=10)
    learnt_coeffs = coeffs.linear.weight.detach().clone().t().numpy()

    Params.equation = print_learnt_equation(learnt_coeffs, Params)

    print(f"\n\n{'-' * len(Params.equation)}\n{'The learnt equation is:'.center(len(Params.equation))}\n{Params.equation}\n{'-' * len(Params.equation)}")
# Out:
#  [Iter 3/3] [Epoch 2000/2000] [Training loss: 1.91e-04] [Learning rate: 1.00e-02]
#
# ------------------------------------
#       The learnt equation is:
# 0.109 cos(12.6 t) -20.815 x -2.948 y
# ------------------------------------

# %%
-0.0658-2.948
# Out:
# -3.0138

# %%
learned_points = np.zeros_like(x)
learned_points[0] = Params.x0
u_middle = 0.5 * (u[:-1] + u[1:])

for k, (t_, u_1, u_m, u_2) in enumerate(zip(ts[1:], u[:-1], u_middle, u[1:]), start=1):
    learned_points[k] = rk4th_onestep(learned_model, learned_points[k-1], u_1, u_m, u_2, t_, learnt_coeffs,timestep=Params.timestep * Params.reduce_step)
# for k, t_ in enumerate(ts[1:], start=1):
#     learned_points[k] = rk4th_onestep(learned_model, learned_points[k-1], t_, learnt_coeffs, timestep=Params.timestep * Params.reduce_step)

# %%
_, (ax1, ax2) = plt.subplots(nrows=2, figsize=(16,8))

ax1.plot(ts, learned_points[:, 0], "k--", linewidth=2, label='RK4-SINDy')
ax1.plot(ts, x[:, 0], c="blue", alpha=0.3, linewidth=4, label='Measurements')
ax2.plot(ts, learned_points[:, 1], "k--", linewidth=2, label='RK4-SINDy')
ax2.plot(ts, x[:, 1], c="blue", alpha=0.3, linewidth=4, label='Measurements')

plt.xlabel(r"$t$ [s]", fontsize=24)
ax1.set_ylabel(r"$x(t)$ [m]", fontsize=24)
ax2.set_ylabel(r"$\dot{x}(t)$ [m/s]", fontsize=24)


ax1.set_xticks(np.arange(0, 4.1, 0.5), np.arange(0, 4.1, 0.5), fontsize=20)
ax1.set_yticks(np.arange(-0.003, 0.0041, 0.001),np.arange(-0.003, 0.0041, 0.001), fontsize=20)
ax2.set_xticks(np.arange(0, 4.1, 0.5), np.arange(0, 4.1, 0.5), fontsize=20)
ax2.set_yticks(np.arange(-0.04, 0.041, 0.02),np.arange(-0.04, 0.041, 0.02), fontsize=20)

# ax1.set_ylim((-0.005, 0.005))
# ax2.set_ylim((-0.05, 0.05))
ax1.set_xlim((-0.1, 1.01 * ts[-1]))
ax2.set_xlim((-0.1, 1.01 * ts[-1]))
plt.legend(fontsize=20, bbox_to_anchor=(1., 2.6))

ax1.yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) 
ax2.yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}')) 

plt.show()

# %%
with open('\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\given_meas_u.npy', 'rb') as f:
    learnt_1 = np.load(f)
with open('\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\not_given_meas_u.npy', 'rb') as f:
    learnt_2 = np.load(f)
with open('\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\given_wrong_u.npy', 'rb') as f:
    learnt_3 = np.load(f)

# %%
_, (ax1, ax2) = plt.subplots(nrows=2, figsize=(16,8))

ax1.plot(ts, learnt_1[:, 0], "k--", linewidth=2, label='RK4-SINDy (a)')
ax1.plot(ts, learnt_2[:, 0], "g--", linewidth=2, label='RK4-SINDy (b)')
ax1.plot(ts, learnt_3[:, 0], "r--", linewidth=2, label='RK4-SINDy (c)')
ax1.plot(ts, learned_points[:, 0], "y", alpha=0.5, linewidth=4, label='Ground truth')
# ax1.plot(ts, x[:, 0], c="blue", alpha=0.3, linewidth=4, label='Measurements')
ax1.scatter(ts, x[:, 0], c="blue", alpha=0.3, label="Measurements", marker='.')#, markersize=5, label="Measurements")
ax2.plot(ts, learnt_1[:, 1], "k--", linewidth=2, label='RK4-SINDy (a)')
ax2.plot(ts, learnt_2[:, 1], "g--", linewidth=2, label='RK4-SINDy (b)')
ax2.plot(ts, learnt_3[:, 1], "r--", linewidth=2, label='RK4-SINDy (c)')
ax2.plot(ts, learned_points[:, 1], "y", alpha=0.5, linewidth=4, label='Ground truth')
# ax2.plot(ts, x[:, 1], c="blue", alpha=0.3, linewidth=4, label='Measurements')
ax2.scatter(ts, x[:, 1], c="blue", alpha=0.3, label="Measurements", marker='.')#, markersize=5, label="Measurements")

plt.xlabel(r"$t$ [s]", fontsize=24)
ax1.set_ylabel(r"$x(t)$ [m]", fontsize=24)
ax2.set_ylabel(r"$\dot{x}(t)$ [m/s]", fontsize=24)


ax1.set_xticks(np.arange(0, 4.1, 0.5), np.arange(0, 4.1, 0.5), fontsize=20)
ax1.set_yticks(np.arange(-0.003, 0.0041, 0.001),np.arange(-0.003, 0.0041, 0.001), fontsize=20)
ax2.set_xticks(np.arange(0, 4.1, 0.5), np.arange(0, 4.1, 0.5), fontsize=20)
ax2.set_yticks(np.arange(-0.05, 0.051, 0.02),np.arange(-0.05, 0.051, 0.02), fontsize=20)

ax1.set_ylim((-0.004, 0.0045))
ax2.set_ylim((-0.06, 0.06))
ax1.set_xlim((-0.1, 1.01 * ts[-1]))
ax2.set_xlim((-0.1, 1.01 * ts[-1]))
plt.legend(fontsize=20, bbox_to_anchor=(1., 1.4))

ax1.yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) 
ax2.yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}')) 

plt.show()

# %%
with open('\\\\tudelft.net\\staff-homes\\L\\cllathourakis\\Desktop\\ResearchAssistant\\research\\code\\current\\given_wrong_u.npy', 'wb') as f:
    np.save(f, learned_points)

# %%
# def temp_model(x, t):
#     # if np.abs(x[1]) < 1e-5 and np.abs(np.cos(1.2 * t) - x[0]) <= 0.5:
#     #     friction_force = np.cos(1.2 * t) - x[0]
#     # else:
#     #     friction_force = 0.5 * np.sign(x[1])
#     # return np.array([x[1], - 0.1 * x[1] - x[0] - friction_force + np.cos(1.2 * t)])
#     return np.array([x[1], - 0.1 * x[1] - x[0] - 0.5 * np.sign(x[1]) + np.cos(1.2 * t)])

# %%
def temp_model(x, u, t):
    return np.array([x[1], 
                     - 358.706 * x[0] * (150 / 98)
                     - 0.0658 * x[1] * (150 / 98)
                     - 0.0856 * (150 / 98) * np.sign(x[1]) 
                     + 358.706 * u[0] 
                     + 0.0658 * u[1]])

# %%
def temp_model_2(x, t):
    return np.array([x[1], 
                     - 358.706 * x[0] * (150 / 98)
                     - 0.0658 * x[1] * (150 / 98)
                     - 0.0856 * (150 / 98) * np.sign(x[1]) 
                    #  + 358.706 * u[0] 
                    #  + 0.0658 * u[1]
                     + 358.706 * displsExc.max() * np.cos(0.995 * forcing_freq * t + phi) 
                     - 0.0658 * 0.995 * forcing_freq * displsExc.max() * np.sin(0.995 * forcing_freq * t + phi)])

# %%
def rk4th_onestep(model, x, u_1, u_m, u_2, t=0, timestep=1e-2):
    k1 = model(x, u_1, t)
    k2 = model(x + 0.5 * timestep * k1, u_m, t + 0.5 * timestep)
    k3 = model(x + 0.5 * timestep * k2, u_m, t + 0.5 * timestep)
    k4 = model(x + 1.0 * timestep * k3, u_2, t + 1.0 * timestep)
    return x + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timestep

# %%
def rk4th_onestep_2(model, x, t=0, timestep=1e-2):
    k1 = model(x, t)
    k2 = model(x + 0.5 * timestep * k1, t + 0.5 * timestep)
    k3 = model(x + 0.5 * timestep * k2, t + 0.5 * timestep)
    k4 = model(x + 1.0 * timestep * k3, t + 1.0 * timestep)
    return x + (1 / 6) * (k1 + 2 * k2 + 2 * k3 + k4) * timestep

# %%
u_middle = 0.5 * (u[:-1] + u[1:])

# %%
x_manual = np.zeros((ts.shape[0], 2))
x_manual[0] = Params.x0

for c, t in enumerate(ts[1:], start=1):
    x_manual[c] = rk4th_onestep(temp_model, x_manual[c-1], u[c-1], u_middle[c-1], u[c], t=t, timestep=Params.timestep)

# %%
rel_motion = x - u

# %%
rel_motion.shape
# Out:
# (400, 2)

# %%
_, ax = plt.subplots(nrows=2, figsize=(20, 10))

ax[0].plot(ts, x_manual[:, 0], label="manual RK4")
# ax[0].plot(times, learned_points[:, 0], label="ID")
# ax[0].plot(ts, x_manual_3[:, 0], label="manual RK4 - NEW")
ax[0].plot(ts, u[:, 0], label="unmodified")
ax[1].plot(ts, x_manual[:, 1], label="manual RK4")
# ax[1].plot(times, learned_points[:, 1], label="ID")
# ax[1].plot(ts, x_manual_3[:, 1], label="manual RK4 - NEW")
ax[0].set_xlim((0, 10))
ax[1].set_xlim((0, 10))
ax[1].plot(ts, u[:, 1], label="unmodified")
plt.legend()
plt.show()

# %%
_, ax = plt.subplots(nrows=2, figsize=(20, 10))

# ax[0].plot(times, x_manual[:, 0], label="manual RK4")
# ax[0].plot(times, learned_points[:, 0], label="ID")
# ax[0].plot(ts, x_manual_3[:, 0], label="manual RK4 - NEW")
ax[0].plot(times, rel_motion[:, 0], label="unmodified")
# ax[1].plot(times, x_manual[:, 1], label="manual RK4")
# ax[1].plot(times, learned_points[:, 1], label="ID")
# ax[1].plot(ts, x_manual_3[:, 1], label="manual RK4 - NEW")
ax[1].plot(times, rel_motion[:, 1], label="unmodified")
plt.legend()
plt.show()

# %%
_, (ax1, ax2) = plt.subplots(nrows=2, figsize=(16,8))
ax1.plot(ts, x_learnt[:, 0], "k--", linewidth=2, label="RK4-SINDy")
ax1.plot(ts, x[:, 0], c="blue", alpha=0.3, linewidth=4, label='Measurements')
ax2.plot(ts, x_learnt[:, 1], "k--", linewidth=2, label="RK4-SINDy")
ax2.plot(ts, x[:, 1], c="blue", alpha=0.3, linewidth=4, label='Measurements')
plt.xlabel(r"$t$ [s]", fontsize=24)
ax1.set_ylabel(r"$x(t)$ [m]", fontsize=24)
ax2.set_ylabel(r"$\dot{x}(t)$ [m/s]", fontsize=24)
# ax1.set_xticks(np.arange(8.1), np.arange(8.1), fontsize=20)
# ax1.set_yticks(np.arange(-0.0075, 0.0076, 0.0025),np.arange(-0.0075, 0.0076, 0.0025), fontsize=20)
# ax2.set_xticks(np.arange(8.1), np.arange(8.1), fontsize=20)
# ax2.set_yticks(np.arange(-0.20, 0.21, 0.1),np.arange(-0.20, 0.21, 0.1), fontsize=20)
ax1.set_xlim((-0.1, 1.01 * ts[-1]))
ax2.set_xlim((-0.1, 1.01 * ts[-1]))
plt.legend(fontsize=20, bbox_to_anchor=(1., 2.6))

ax1.yaxis.set_major_formatter(StrMethodFormatter('{x:,.4f}')) 
ax2.yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}')) 

plt.show()
